# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
result = pd.read_csv('results/list58.csv')
plt.plot(result, 'm')
plt.title('Vanilla DQN')
plt.xlabel('Every 100 games')
plt.ylabel('Winning rate of Black')
# Change the Name!!!!!!!!!!!!!!! Not to lose any plots!!!!!!!!!!!!
plt.savefig('plots/ChangeThis.png')
plt.show()
