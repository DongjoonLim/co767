# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(17,13))
result = pd.read_csv('results/list36.csv')
plt.plot(result, 'm')
plt.title('Vanilla DQN')
plt.xlabel('Every 100 games')
plt.ylabel('Winning rate of Black')
plt.show()
